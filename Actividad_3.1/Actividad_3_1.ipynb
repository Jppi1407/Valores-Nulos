# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('Ventas_totales.csv')
df.head(5)
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0      01/01/17                    27858.9                    27477.3
# 1      01/02/17                    25994.2                    25223.4
# 2      01/03/17                    27780.0                    26334.3
# 3      01/04/17                    29134.3                    27045.9
# 4      01/05/17                    27969.0                    25631.9
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 27858872.08   27591730.13       267141.956
# 1                 25994200.17   25749179.40       245020.769
# 2                 27780006.52   27472228.72       307777.804
# 3                 29134272.22   28827479.49       306792.733
# 4                 27969004.68   27569311.41       399693.262
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 0                27858872.08  1.023010e+07      6864575.384       9047205.493
# ...

# %%
#Identificar valores nulos por columna
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Realizamos una copia del dataframe
df2 = df
df2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0       01/01/17                    27858.9                    27477.3
# 1       01/02/17                    25994.2                    25223.4
# 2       01/03/17                    27780.0                    26334.3
# 3       01/04/17                    29134.3                    27045.9
# 4       01/05/17                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60      01/01/22                   154517.1                    45463.4
# 61      01/02/22                   152202.6                    23802.1
# 62      01/03/22                       16.5                    24612.4
# 63      01/04/22                   177148.1                    24140.5
# 64      01/05/22                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Sustituir valores nulos con mediana
df2["salon_ventas"]=df2["salon_ventas"].fillna(round(df["salon_ventas"].median(),1))

# %%
# Calcular valores nulos por columna
valores_nulos = df.isnull().sum()
# Convertir a DataFrame para mayor legibilidad
valores_nulos = valores_nulos.reset_index()
valores_nulos.columns = ['Columna', 'Valores_Nulos']

print(valores_nulos)
# Out:
#                                 Columna  Valores_Nulos
# 0                         indice_tiempo              0
# 1             ventas_precios_corrientes              0
# 2             ventas_precios_constantes              0
# 3            ventas_totales_canal_venta              0
# 4                          salon_ventas              0
# 5                       canales_on_line              0
# 6             ventas_totales_medio_pago              0
# 7                              efectivo              0
# 8                       tarjetas_debito              1
# 9                      tarjetas_credito              7
# 10                         otros_medios              1
# 11       ventas_totales_grupo_articulos              0
# 12    subtotal_ventas_alimentos_bebidas             10
# 13                              bebidas              1
# 14                              almacen              2
# 15                            panaderia              1
# ...

# %%
#Sustituir valores nulos por un valor numérico en  concreto
df2["tarjetas_debito"]= df["tarjetas_debito"].fillna(10)
pd.options.display.max_rows = 50
df2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0       01/01/17                    27858.9                    27477.3
# 1       01/02/17                    25994.2                    25223.4
# 2       01/03/17                    27780.0                    26334.3
# 3       01/04/17                    29134.3                    27045.9
# 4       01/05/17                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60      01/01/22                   154517.1                    45463.4
# 61      01/02/22                   152202.6                    23802.1
# 62      01/03/22                       16.5                    24612.4
# 63      01/04/22                   177148.1                    24140.5
# 64      01/05/22                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
display(df2.isnull().sum())
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Sustituir valores nulos con promedio o media
df2["tarjetas_credito"]=df2["tarjetas_credito"].fillna(round(df["tarjetas_credito"].mean(),1))
display(df2.isnull().sum())
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        0
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia adelante  "forward fill" ("ffill")
#Filtro por columnas
df2["otros_medios"] =df2["otros_medios"].fillna(method="ffill")

display(df2.isnull().sum())
# Out:
# /var/folders/wy/pt9_jxts4m57dmqwnkry3f600000gn/T/ipykernel_5588/85691791.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["otros_medios"] =df2["otros_medios"].fillna(method="ffill")
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        0
# otros_medios                            0
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# ...

# %%
#Sustituir valores nulos con promedio o media
df2["subtotal_ventas_alimentos_bebidas"]=df2["subtotal_ventas_alimentos_bebidas"].fillna(round(df["subtotal_ventas_alimentos_bebidas"].mean(),1))

display(df2.isnull().sum())
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                2
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#Sustituir valores nulos por valores no nulos hacia atrás backward fill" ("bfill")
#Filtro por columnas
df2["bebidas"] =df2["bebidas"].fillna(method="bfill")
df2["panaderia"] =df2["panaderia"].fillna(method="bfill")
df2["lacteos"] =df2["lacteos"].fillna(method="bfill")
df2["carnes"] =df2["carnes"].fillna(method="bfill")
df2["verduleria_fruteria"] =df2["verduleria_fruteria"].fillna(method="bfill")
df2["alimentos_preparados_rotiseria"] =df2["alimentos_preparados_rotiseria"].fillna(method="bfill")

display(df2.isnull().sum())
# Out:
# /var/folders/wy/pt9_jxts4m57dmqwnkry3f600000gn/T/ipykernel_5588/393412353.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["bebidas"] =df2["bebidas"].fillna(method="bfill")
# /var/folders/wy/pt9_jxts4m57dmqwnkry3f600000gn/T/ipykernel_5588/393412353.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["panaderia"] =df2["panaderia"].fillna(method="bfill")
# /var/folders/wy/pt9_jxts4m57dmqwnkry3f600000gn/T/ipykernel_5588/393412353.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["lacteos"] =df2["lacteos"].fillna(method="bfill")
# ...

# %%
#Sustituir valores nulos con promedio o media
df2["almacen"]=df2["subtotal_ventas_alimentos_bebidas"].fillna(round(df["almacen"].mean(),1))
df2["indumentaria_calzado_textiles_hogar"]=df2["indumentaria_calzado_textiles_hogar"].fillna(round(df["indumentaria_calzado_textiles_hogar"].mean(),1))
df2["electronicos_articulos_hogar"]=df2["electronicos_articulos_hogar"].fillna(round(df["almacen"].mean(),1))
df2["otros"]=df2["otros"].fillna(round(df["otros"].mean(),1))

display(df2.isnull().sum())
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
df2.to_csv("Ventas_totales_limpio.csv", index = False)
